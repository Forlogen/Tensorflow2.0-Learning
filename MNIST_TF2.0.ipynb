# %%
from __future__ import absolute_import,division,print_function,unicode_literals
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow.keras as keras
import numpy as np
import os
import time

tf.__version__
# Out:
# '2.0.0-rc1'

# %%
mnist = tfds.image.MNIST()
mnist = tfds.builder('mnist')

assert mnist.info.features['image'].shape == (28,28,1)
assert mnist.info.featurres['label'].num_classes == 10
assert mnist.info.splits['train'].num_examples == 60000
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     353         else:
# --> 354             conn.request(method, url, **httplib_request_kw)
#     355
#
# D:\Anaconda\envs\tensorflow-2.0\lib\http\client.py in request(self, method, url, body, headers, encode_chunked)
#    1253         """Send a complete request to the server."""
# -> 1254         self._send_request(method, url, body, headers, encode_chunked)
#    1255
#
# D:\Anaconda\envs\tensorflow-2.0\lib\http\client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1299             body = _encode(body, 'body')
# -> 1300         self.endheaders(body, encode_chunked=encode_chunked)
#    1301
#
# D:\Anaconda\envs\tensorflow-2.0\lib\http\client.py in endheaders(self, message_body, encode_chunked)
#    1248             raise CannotSendHeader()
# -> 1249         self._send_output(message_body, encode_chunked=encode_chunked)
#    1250
#
# D:\Anaconda\envs\tensorflow-2.0\lib\http\client.py in _send_output(self, message_body, encode_chunked)
#    1035         del self._buffer[:]
# -> 1036         self.send(msg)
#    1037
#
# D:\Anaconda\envs\tensorflow-2.0\lib\http\client.py in send(self, data)
#     973             if self.auto_open:
# --> 974                 self.connect()
#     975             else:
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\connection.py in connect(self)
#     180     def connect(self):
# --> 181         conn = self._new_conn()
#     182         self._prepare_conn(conn)
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x000001853D6D72E8>: Failed to establish a new connection: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\urllib3\util\retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     398         if new_retry.is_exhausted():
# --> 399             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     400
#
# MaxRetryError: HTTPConnectionPool(host='storage.googleapis.com', port=80): Max retries exceeded with url: /tfds-data/?prefix=dataset_info/mnist/1.0.0/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001853D6D72E8>: Failed to establish a new connection: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-3-2dd68a9ada62> in <module>
# ----> 1 mnist = tfds.image.MNIST()
#       2 mnist = tfds.builder('mnist')
#       3
#       4 assert mnist.info.features['image'].shape == (28,28,1)
#       5 assert mnist.info.featurres['label'].num_classes == 10
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\tensorflow_datasets\core\api_utils.py in disallow_positional_args_dec(fn, instance, args, kwargs)
#      50     _check_no_positional(fn, args, ismethod, allowed=allowed)
#      51     _check_required(fn, kwargs)
# ---> 52     return fn(*args, **kwargs)
#      53
#      54   return disallow_positional_args_dec(wrapped)  # pylint: disable=no-value-for-parameter
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\tensorflow_datasets\core\dataset_builder.py in __init__(self, data_dir, config, version)
#     186     else:  # Use the code version (do not restore data)
#     187       logging.info("Load pre-computed datasetinfo (eg: splits) from bucket.")
# --> 188       self.info.initialize_from_bucket()
#     189
#     190   def _pick_version(self, requested_version):
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\tensorflow_datasets\core\dataset_info.py in initialize_from_bucket(self)
#     405     # files. They are copied locally and then loaded.
#     406     tmp_dir = tempfile.mkdtemp("tfds")
# --> 407     data_files = gcs_utils.gcs_dataset_info_files(self.full_name)
#     408     if not data_files:
#     409       return
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\tensorflow_datasets\core\utils\gcs_utils.py in gcs_dataset_info_files(dataset_dir)
#      62   prefix = posixpath.join(GCS_DATASET_INFO_DIR, dataset_dir, "")
#      63   # Filter for this dataset
# ---> 64   filenames = [el for el in gcs_files(prefix_filter=prefix)
#      65                if el.startswith(prefix) and len(el) > len(prefix)]
#      66   return filenames
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\tensorflow_datasets\core\utils\gcs_utils.py in gcs_files(prefix_filter)
#      52 def gcs_files(prefix_filter=None):
#      53   """List all files in GCS bucket."""
# ---> 54   top_level_xml_str = download_gcs_file("", prefix_filter=prefix_filter)
#      55   xml_root = ElementTree.fromstring(top_level_xml_str)
#      56   filenames = [el[0].text for el in xml_root if el.tag.endswith("Contents")]
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\tensorflow_datasets\core\utils\gcs_utils.py in download_gcs_file(path, out_fname, prefix_filter)
#      38     url += "?prefix=%s" % prefix_filter
#      39   stream = bool(out_fname)
# ---> 40   resp = requests.get(url, stream=stream)
#      41   if not resp.ok:
#      42     raise ValueError("GCS bucket inaccessible")
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# D:\Anaconda\envs\tensorflow-2.0\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='storage.googleapis.com', port=80): Max retries exceeded with url: /tfds-data/?prefix=dataset_info/mnist/1.0.0/ (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x000001853D6D72E8>: Failed to establish a new connection: [WinError 10051] 向一个无法连接的网络尝试了一个套接字操作。',))
